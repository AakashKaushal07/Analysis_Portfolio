# %%
from django.db.models import Q
from base_app.models import ConfigItems
from leagues.models import Competition, Season
from base_app.decorators import cleanup_selenium_instances,timed_retry
from games.models import Game

import pandas as pd
import re
from datetime import datetime
from pprint import pprint

# %%
BASE_FILE_DIR = "D:\All Season Data\Files"
BASE_LOGS_DIR = "D:\All Season Data\Logs"

# %%
def filter_file_details(filename):
    """
    Extracts competition, season, and type from a filename using a regex.

    Args:
        filename (str): The name of the file to parse.

    Returns:
        dict: A dictionary containing the extracted details, or None if the
              filename does not match the expected format.
    """
    # Regex to capture competition, season, and type from the filename
    # The pattern matches:
    # 1. A non-greedy group for the competition name (.*?)
    # 2. A specific group for the season, which can be 'YYYY' or 'YYYY_YYYY'
    # 3. A word group for the type (\w+)
    regex = r'^(.*?)_(\d{4}(?:_\d{4})?)_(\w+)\.xlsx$'
    match = re.search(regex, filename)

    if match:
        # Extract the captured groups and clean them up
        competition_name = match.group(1).replace('_', ' ')
        season_value = match.group(2).replace('_', '/')
        type_value = match.group(3)

        return {
            'competition': competition_name,
            'season': season_value,
            'type': type_value
        }
    else:
        return {}

def filter_log_file_details(filename):
    league,season = [x for x in filename.split("_-_")][:2]
    
    return {
            'competition': league.replace("_"," "),
            'season': season.replace("_","/"),
        }

# %%
def get_all_files(directory_path="D:\All Season Data\Files"):
    files_data = []
    fl = False
    for lvl_1,lvl_2,file_list in os.walk(directory_path,):
        if file_list == []:
            continue
        batch_no = next((x.split("_")[0].capitalize() for x in lvl_1.split("\\") if "_MetaData" in x),"B6")
        confederation,region = [x.strip(" ") for x in lvl_1.split("\\") ][-2:]
        for file_name in file_list :
            df = None
            temp = {}
            temp['batch'] = batch_no
            temp['confederation'] = confederation
            temp['region'] = region
            temp = {**temp,**filter_file_details(file_name)}
            try :
                df = pd.read_excel(f"{lvl_1}/{file_name}")
                temp['matches'] = df.shape[0]
                temp['team_counts'] = len(set(list(set(df['home_team']))+list(set(df['away_team'])))) 
                del df
            except :
                temp['team_counts'] = 0 
                temp['matches'] = 0
                if dl:
                    del df
            files_data.append(temp)
        
    return pd.DataFrame(files_data)
file_df = get_all_files()

# %%
# list(set(file_df['competition']))[0]
file_df[file_df['competition'] == '1 SNL'].sort_values('season')
# Out:
#      batch confederation    region competition     season    type  matches  \
# 1546    B4          UEFA  Slovenia       1 SNL  2017/2018  events      180
# 3121   Old          UEFA  Slovenia       1 SNL  2017/2018  events      180
# 2199    B5          UEFA  Slovenia       1 SNL  2017/2018  events      180
# 2504    B6          UEFA  Slovenia       1 SNL  2017/2018  events       47
# 1547    B4          UEFA  Slovenia       1 SNL  2018/2019  events        4
# 3122   Old          UEFA  Slovenia       1 SNL  2018/2019  events        4
# 2505    B6          UEFA  Slovenia       1 SNL  2018/2019  events        1
# 2200    B5          UEFA  Slovenia       1 SNL  2018/2019  events        4
# 1548    B4          UEFA  Slovenia       1 SNL  2019/2020  events      180
# 2506    B6          UEFA  Slovenia       1 SNL  2019/2020  events        3
# 2201    B5          UEFA  Slovenia       1 SNL  2019/2020  events      180
# 3123   Old          UEFA  Slovenia       1 SNL  2019/2020  events      180
# 2507    B6          UEFA  Slovenia       1 SNL  2020/2021  events       43
# 3124   Old          UEFA  Slovenia       1 SNL  2020/2021  events      180
# 2202    B5          UEFA  Slovenia       1 SNL  2020/2021  events      180
# 1549    B4          UEFA  Slovenia       1 SNL  2020/2021  events      180
# 2508    B6          UEFA  Slovenia       1 SNL  2021/2022  events      180
# 3125   Old          UEFA  Slovenia       1 SNL  2021/2022  events      180
# 1550    B4          UEFA  Slovenia       1 SNL  2021/2022  events      180
# 2203    B5          UEFA  Slovenia       1 SNL  2021/2022  events      180
# 3126   Old          UEFA  Slovenia       1 SNL  2022/2023  events      146
# 1551    B4          UEFA  Slovenia       1 SNL  2022/2023  events      146
# 2509    B6          UEFA  Slovenia       1 SNL  2022/2023  events       21
# 2204    B5          UEFA  Slovenia       1 SNL  2022/2023  events      146
# 2205    B5          UEFA  Slovenia       1 SNL  2023/2024  events      180
# 3127   Old          UEFA  Slovenia       1 SNL  2023/2024  events      180
# 1552    B4          UEFA  Slovenia       1 SNL  2023/2024  events      180
# 2510    B6          UEFA  Slovenia       1 SNL  2023/2024  events        5
# 2206    B5          UEFA  Slovenia       1 SNL  2024/2025  events       23
# 1553    B4          UEFA  Slovenia       1 SNL  2024/2025  events       23
# 2511    B6          UEFA  Slovenia       1 SNL  2024/2025  events        1
# 3128   Old          UEFA  Slovenia       1 SNL  2024/2025  events       23
#
#       team_counts
# 1546           10
# 3121           10
# 2199           10
# 2504           10
# 1547            8
# 3122            8
# 2505            2
# 2200            8
# 1548           10
# 2506            6
# 2201           10
# 3123           10
# 2507           10
# 3124           10
# 2202           10
# 1549           10
# 2508           10
# 3125           10
# 1550           10
# 2203           10
# 3126           10
# 1551           10
# 2509           10
# 2204           10
# 2205           10
# 3127           10
# 1552           10
# 2510           10
# 2206           10
# 1553           10
# 2511            2
# 3128           10

# %%
def parse_and_look_at_errors(file_path) :
    with open(file_path,"r",encoding='utf-8') as f :
        all_logs = [f"2025{x}".replace("\n"," ").replace("\t"," ").replace('[','').replace(']','') for x in f.read().split("\n2025")]
    err_cnts = {
        "Total Error Count" : 0,        
        "TimeoutException" : 0,
        "ReadTimeoutError" : 0,
        "InvalidSessionIdException" : 0,
        "NoSuchWindowException" : 0,
        "AttributeError" : 0,
        "ValueError" : 0,
        "NoSuchElementException" : 0,
        "HTTPConnectionPool" : 0
    }
    for i,x in enumerate(all_logs) :
        if ('Error' in x or 'Exception' in x.lower()) and 'Cleanup failed' not in x:
           err_cnts["Total Error Count"] += 1
        for k,v in err_cnts.items() :
            if k in x :
                err_cnts[k] = v+1
    return err_cnts

def parse_and_look_fixture_count(file_path) :
    with open(file_path,"r",encoding='utf-8') as f :
        all_logs = [f"2025{x}".replace("\n"," ").replace("\t"," ").replace('[','').replace(']','') for x in f.read().split("\n2025")]
    count_logs = [x for x in all_logs if 'Found a total of ' in x and ' matches' in x ]
    # print(file_path.split('/')[-1],count_logs)
    for x in all_logs :
        match = re.search(r'Found a total of (\d+) matches', x)
    
        if match:
            match_count = int(match.group(1))
            return match_count
    return None

# %%
def get_all_logs(directory_path="D:\All Season Data\Logs"):
    log_data = []
    all_errs = []
    done_list = []
    for lvl_1,lvl_2,file_list in os.walk(directory_path,):
        if file_list == []:
            continue
        batch_no = next((x.split("_")[0].capitalize() for x in lvl_1.split("\\") if "_runtime" in x),"B6")
        confederation,region = [x.strip(" ") for x in lvl_1.split("\\") ][-2:]
        for file_name in file_list :
            # num = file_name.split("_")[-1]
            # proc_num  = int(num) if num.isdigit() else "SHINSHINAKIBABLABU"
            # file_name = file_name.replace(f"_{proc_num}","")
            
            # if file_name in done_list :
            #     print("no need its done : ",file_name)
            #     continue
            temp = {}
            temp['batch'] = batch_no
            temp['confederation'] = confederation
            temp['region'] = region
            temp = {**temp,**filter_log_file_details(file_name)}
            temp['fixture_count'] = parse_and_look_fixture_count(f"{lvl_1}/{file_name}")
            # temp = {**temp,**parse_and_look_at_errors(f"{lvl_1}/{file_name}")}
            comp_obj = Competition.objects.get(competition_name=temp['competition'])
            temp['confederation']= comp_obj.confederation
            temp['region'] = comp_obj.country
            temp['competition'] = comp_obj.name_scoresaway
            temp['competition_alt'] = comp_obj.competition_name
            log_data.append(temp)
            # done_list.append(file_name)
    return pd.DataFrame(log_data)
    # return pd.DataFrame(logs_data)
err_df = get_all_logs()

# %%
merged_df = pd.merge(file_df[file_df['type']=='events'],err_df,how='left',on=['batch','confederation','region','competition','season'])

# %%
err_df.head()
# Out:
#   batch confederation     region                 competition     season  \
# 0    A1          UEFA    Germany               2. Bundesliga  2022/2023
# 1    A1          UEFA    Germany               2. Bundesliga  2023/2024
# 2    A1           AFC  Australia                A-League Men  2018/2019
# 3    A1           AFC  Australia                A-League Men  2024/2025
# 4    A1           AFC        AFC  AFC Champions League Elite       2022
#
#    fixture_count       competition_alt
# 0          306.0         2. Bundesliga
# 1          306.0         2. Bundesliga
# 2          140.0              A-League
# 3          176.0              A-League
# 4          137.0  AFC Champions League

# %% [markdown]
# There are a lot of info about all batches, so considering max num of fixtures from the logs list and only B^ for flie list

# %%
clean_df = err_df[['confederation','region','competition','competition_alt','season']].drop_duplicates()

# %%
fixture_df = pd.DataFrame()
for i,row in clean_df.iterrows():
    confed = row.get('confederation')
    reg = row.get('region')
    comp = row.get('competition')
    seas = row.get('season')
    
    # Build the query safely using @
    query_string = "confederation == @confed and region == @reg and competition == @comp and season == @seas"
    
    # Execute the query
    temp_df = err_df.query(query_string)
    # temp_df = err_df.query(f"confederation=='{row.get('confederation')}' AND region=='{row.get('region')}' AND competition=='{row.get('competition')}'  AND season=='{row.get('season')}'")
    temp_df = temp_df.dropna().sort_values('fixture_count')
    # print(temp_df['fixture_count'])
    if temp_df.shape[0] > 0 :
        fixture_df = pd.concat([fixture_df, temp_df.head(1)], ignore_index=True)

# %%
last_batch = file_df[(file_df['type']=='events') & ((file_df['batch']=='B6') | (file_df['batch']=='Old'))]

# %%
print("\n--- Merged DF Columns ---")
print(merged_df.columns)
# Out:
# --- Merged DF Columns ---
# Index(['batch', 'confederation', 'region', 'competition', 'season', 'type',
#        'matches', 'team_counts', 'fixture_count', 'competition_alt'],
#       dtype='object')

# %%
merged_df = pd.merge(last_batch,fixture_df,how='left',on=['confederation','region','competition','season'])
merged_df.to_excel("COMPARE_CLEANED_DATA.xlsx",index=False)

# %%
fixture_df.to_excel("All_Fixture_Counts.xlsx",index=False)

# %%
misc_df = last_batch.reset_index().drop('index',axis=1)

# %%
misc_df.to_excel("MISC_DF.xlsx",index=False)

# %%
comp_alt_map = {}
for i,row in fixture_df[['competition','competition_alt']].iterrows():
    comp = row.get('competition')
    comp_alt = row.get('competition_alt')
    # if "1" in comp or "1" in comp_alt :
        # print(comp,comp_alt)
    if comp and comp_alt and comp not in comp_alt_map:
        comp_alt_map[comp] = comp_alt

# %%
issues = []
new_comp,new_comp_alt = "",""
for i, row in misc_df.iterrows():
    confed = row.get('confederation')
    reg = row.get('region')
    comp = row.get('competition')
    comp_alt = str(comp_alt_map.get(comp))
    seas = row.get('season')
    comp_sm = SA_TO_COMP_NAME_MAP.get(comp)
    comp_fm = FM_TO_COMP_NAME_MAP.get(comp)
    # Build the query safely using @
    if "1" in comp :
        new_comp = comp.replace("1 ","1. ")
        new_comp_alt = comp_alt.replace("1 ","1. ")
        query_string = "confederation == @confed and region == @reg and ((competition == @comp or competition_alt == @comp_alt) or (competition == @new_comp or competition_alt == @new_comp_alt)) and season == @seas"
    elif "2" in comp:
        new_comp = comp.replace("2 ","2. ")
        new_comp_alt = comp_alt.replace("2 ","2. ")
        query_string = "confederation == @confed and region == @reg and ((competition == @comp or competition_alt == @comp_alt) or (competition == @new_comp or competition_alt == @new_comp_alt)) and season == @seas"
    else:
        query_string = "confederation == @confed and region == @reg and (competition == @comp or competition_alt == @comp_alt) and season == @seas"
        
    df = fixture_df.query(query_string)
    if df.shape[0] :
        misc_df.loc[i,'total_fixtures'] = df['fixture_count'].iloc[0]
    else:
        if "25" in seas :
            # print("Easy 24/25",f"{confed} | {reg} | {comp} - {comp_alt} | {seas}")
            continue
        print("Problem : ")
        print(f"{confed} | {reg} | {comp} - {comp_alt} | {seas}")
        print("In Fixture : \n"
        f"confederation == '{confed}' and "
        f"region == '{reg}' and "
        f"((competition == '{comp}' OR competition_alt == '{comp_alt}') or "
        f"(competition == '{new_comp}' OR competition_alt == '{new_comp_alt}')) and "
        f"season == {seas}"
        )
        issues.append(f"{confed} | {reg} | {comp} - {comp_alt} | {seas}")
        print()
# Out:
# Problem :
# UEFA | England | League Two - EFL League Two | 2017/2018
# In Fixture :
# confederation == 'UEFA' and region == 'England' and ((competition == 'League Two' OR competition_alt == 'EFL League Two') or (competition == '1. Division' OR competition_alt == 'None')) and season == 2017/2018
#
# Problem :
# UEFA | France | Ligue 1 - Ligue 1 | 2017/2018
# In Fixture :
# confederation == 'UEFA' and region == 'France' and ((competition == 'Ligue 1' OR competition_alt == 'Ligue 1') or (competition == 'Ligue 1' OR competition_alt == 'Ligue 1')) and season == 2017/2018
#
# Problem :
# UEFA | Germany | 2 Bundesliga - None | 2023/2024
# In Fixture :
# confederation == 'UEFA' and region == 'Germany' and ((competition == '2 Bundesliga' OR competition_alt == 'None') or (competition == '2. Bundesliga' OR competition_alt == 'None')) and season == 2023/2024
#
# Problem :
# UEFA | Greece | Super League 1 - Super League Greece | 2018/2019
# In Fixture :
# confederation == 'UEFA' and region == 'Greece' and ((competition == 'Super League 1' OR competition_alt == 'Super League Greece') or (competition == 'Super League 1' OR competition_alt == 'Super League Greece')) and season == 2018/2019
#
# Problem :
# UEFA | Greece | Super League 1 - Super League Greece | 2019/2020
# In Fixture :
# confederation == 'UEFA' and region == 'Greece' and ((competition == 'Super League 1' OR competition_alt == 'Super League Greece') or (competition == 'Super League 1' OR competition_alt == 'Super League Greece')) and season == 2019/2020
#
# Problem :
# UEFA | Greece | Super League 1 - Super League Greece | 2020/2021
# In Fixture :
# confederation == 'UEFA' and region == 'Greece' and ((competition == 'Super League 1' OR competition_alt == 'Super League Greece') or (competition == 'Super League 1' OR competition_alt == 'Super League Greece')) and season == 2020/2021
#
# Problem :
# UEFA | Greece | Super League 1 - Super League Greece | 2021/2022
# In Fixture :
# confederation == 'UEFA' and region == 'Greece' and ((competition == 'Super League 1' OR competition_alt == 'Super League Greece') or (competition == 'Super League 1' OR competition_alt == 'Super League Greece')) and season == 2021/2022
#
# Problem :
# UEFA | Greece | Super League 1 - Super League Greece | 2022/2023
# In Fixture :
# confederation == 'UEFA' and region == 'Greece' and ((competition == 'Super League 1' OR competition_alt == 'Super League Greece') or (competition == 'Super League 1' OR competition_alt == 'Super League Greece')) and season == 2022/2023
#
# Problem :
# UEFA | Israel | Ligat Ha'al - Ligat Ha'Al | 2018/2019
# In Fixture :
# confederation == 'UEFA' and region == 'Israel' and ((competition == 'Ligat Ha'al' OR competition_alt == 'Ligat Ha'Al') or (competition == 'Super League 1' OR competition_alt == 'Super League Greece')) and season == 2018/2019
#
# Problem :
# UEFA | Italy | Serie A - Brasileiro Serie A | 2021/2022
# In Fixture :
# confederation == 'UEFA' and region == 'Italy' and ((competition == 'Serie A' OR competition_alt == 'Brasileiro Serie A') or (competition == 'Super League 1' OR competition_alt == 'Super League Greece')) and season == 2021/2022
#
# Problem :
# UEFA | Italy | Serie A - Brasileiro Serie A | 2022/2023
# In Fixture :
# confederation == 'UEFA' and region == 'Italy' and ((competition == 'Serie A' OR competition_alt == 'Brasileiro Serie A') or (competition == 'Super League 1' OR competition_alt == 'Super League Greece')) and season == 2022/2023
#
# Problem :
# UEFA | Italy | Serie A - Brasileiro Serie A | 2023/2024
# In Fixture :
# confederation == 'UEFA' and region == 'Italy' and ((competition == 'Serie A' OR competition_alt == 'Brasileiro Serie A') or (competition == 'Super League 1' OR competition_alt == 'Super League Greece')) and season == 2023/2024
#
# Problem :
# UEFA | Latvia | Virsliga - Virsliga | 2018
# In Fixture :
# confederation == 'UEFA' and region == 'Latvia' and ((competition == 'Virsliga' OR competition_alt == 'Virsliga') or (competition == 'Super League 1' OR competition_alt == 'Super League Greece')) and season == 2018
#
# Problem :
# UEFA | Latvia | Virsliga - Virsliga | 2019
# In Fixture :
# confederation == 'UEFA' and region == 'Latvia' and ((competition == 'Virsliga' OR competition_alt == 'Virsliga') or (competition == 'Super League 1' OR competition_alt == 'Super League Greece')) and season == 2019
#
# Problem :
# UEFA | Latvia | Virsliga - Virsliga | 2020
# In Fixture :
# confederation == 'UEFA' and region == 'Latvia' and ((competition == 'Virsliga' OR competition_alt == 'Virsliga') or (competition == 'Super League 1' OR competition_alt == 'Super League Greece')) and season == 2020
#
# Problem :
# UEFA | Latvia | Virsliga - Virsliga | 2021
# In Fixture :
# confederation == 'UEFA' and region == 'Latvia' and ((competition == 'Virsliga' OR competition_alt == 'Virsliga') or (competition == 'Super League 1' OR competition_alt == 'Super League Greece')) and season == 2021
#
# Problem :
# UEFA | Latvia | Virsliga - Virsliga | 2022
# In Fixture :
# confederation == 'UEFA' and region == 'Latvia' and ((competition == 'Virsliga' OR competition_alt == 'Virsliga') or (competition == 'Super League 1' OR competition_alt == 'Super League Greece')) and season == 2022
#
# Problem :
# UEFA | Latvia | Virsliga - Virsliga | 2023
# In Fixture :
# confederation == 'UEFA' and region == 'Latvia' and ((competition == 'Virsliga' OR competition_alt == 'Virsliga') or (competition == 'Super League 1' OR competition_alt == 'Super League Greece')) and season == 2023
#
# Problem :
# UEFA | Netherlands | Eerste Divisie - Eerste Divisie | 2018/2019
# In Fixture :
# confederation == 'UEFA' and region == 'Netherlands' and ((competition == 'Eerste Divisie' OR competition_alt == 'Eerste Divisie') or (competition == 'Super League 1' OR competition_alt == 'Super League Greece')) and season == 2018/2019
#
# Problem :
# UEFA | Netherlands | Eerste Divisie - Eerste Divisie | 2019/2020
# In Fixture :
# confederation == 'UEFA' and region == 'Netherlands' and ((competition == 'Eerste Divisie' OR competition_alt == 'Eerste Divisie') or (competition == 'Super League 1' OR competition_alt == 'Super League Greece')) and season == 2019/2020
#
# Problem :
# UEFA | Netherlands | Eerste Divisie - Eerste Divisie | 2020/2021
# In Fixture :
# confederation == 'UEFA' and region == 'Netherlands' and ((competition == 'Eerste Divisie' OR competition_alt == 'Eerste Divisie') or (competition == 'Super League 1' OR competition_alt == 'Super League Greece')) and season == 2020/2021
#
# Problem :
# UEFA | Netherlands | Eerste Divisie - Eerste Divisie | 2022/2023
# In Fixture :
# confederation == 'UEFA' and region == 'Netherlands' and ((competition == 'Eerste Divisie' OR competition_alt == 'Eerste Divisie') or (competition == 'Super League 1' OR competition_alt == 'Super League Greece')) and season == 2022/2023
#
# Problem :
# UEFA | Netherlands | Eredivisie - Eredivisie | 2018/2019
# In Fixture :
# confederation == 'UEFA' and region == 'Netherlands' and ((competition == 'Eredivisie' OR competition_alt == 'Eredivisie') or (competition == 'Super League 1' OR competition_alt == 'Super League Greece')) and season == 2018/2019
#
# Problem :
# UEFA | Netherlands | Eredivisie - Eredivisie | 2019/2020
# In Fixture :
# confederation == 'UEFA' and region == 'Netherlands' and ((competition == 'Eredivisie' OR competition_alt == 'Eredivisie') or (competition == 'Super League 1' OR competition_alt == 'Super League Greece')) and season == 2019/2020
#
# Problem :
# UEFA | Netherlands | Eredivisie - Eredivisie | 2020/2021
# In Fixture :
# confederation == 'UEFA' and region == 'Netherlands' and ((competition == 'Eredivisie' OR competition_alt == 'Eredivisie') or (competition == 'Super League 1' OR competition_alt == 'Super League Greece')) and season == 2020/2021
#
# Problem :
# UEFA | Netherlands | Eredivisie - Eredivisie | 2021/2022
# In Fixture :
# confederation == 'UEFA' and region == 'Netherlands' and ((competition == 'Eredivisie' OR competition_alt == 'Eredivisie') or (competition == 'Super League 1' OR competition_alt == 'Super League Greece')) and season == 2021/2022
#
# Problem :
# UEFA | Netherlands | Eredivisie - Eredivisie | 2022/2023
# In Fixture :
# confederation == 'UEFA' and region == 'Netherlands' and ((competition == 'Eredivisie' OR competition_alt == 'Eredivisie') or (competition == 'Super League 1' OR competition_alt == 'Super League Greece')) and season == 2022/2023
#
# Problem :
# UEFA | Netherlands | Eredivisie - Eredivisie | 2023/2024
# In Fixture :
# confederation == 'UEFA' and region == 'Netherlands' and ((competition == 'Eredivisie' OR competition_alt == 'Eredivisie') or (competition == 'Super League 1' OR competition_alt == 'Super League Greece')) and season == 2023/2024
#
# Problem :
# UEFA | Norway | Eliteserien - Eliteserien | 2018
# In Fixture :
# confederation == 'UEFA' and region == 'Norway' and ((competition == 'Eliteserien' OR competition_alt == 'Eliteserien') or (competition == 'Super League 1' OR competition_alt == 'Super League Greece')) and season == 2018
#
# Problem :
# UEFA | Norway | Eliteserien - Eliteserien | 2020
# In Fixture :
# confederation == 'UEFA' and region == 'Norway' and ((competition == 'Eliteserien' OR competition_alt == 'Eliteserien') or (competition == 'Super League 1' OR competition_alt == 'Super League Greece')) and season == 2020
#
# Problem :
# UEFA | Norway | Eliteserien - Eliteserien | 2021
# In Fixture :
# confederation == 'UEFA' and region == 'Norway' and ((competition == 'Eliteserien' OR competition_alt == 'Eliteserien') or (competition == 'Super League 1' OR competition_alt == 'Super League Greece')) and season == 2021
#
# Problem :
# UEFA | Norway | Eliteserien - Eliteserien | 2022
# In Fixture :
# confederation == 'UEFA' and region == 'Norway' and ((competition == 'Eliteserien' OR competition_alt == 'Eliteserien') or (competition == 'Super League 1' OR competition_alt == 'Super League Greece')) and season == 2022
#
# Problem :
# UEFA | Norway | Eliteserien - Eliteserien | 2023
# In Fixture :
# confederation == 'UEFA' and region == 'Norway' and ((competition == 'Eliteserien' OR competition_alt == 'Eliteserien') or (competition == 'Super League 1' OR competition_alt == 'Super League Greece')) and season == 2023
#
# Problem :
# UEFA | Poland | Ekstraklasa - None | 2017/2018
# In Fixture :
# confederation == 'UEFA' and region == 'Poland' and ((competition == 'Ekstraklasa' OR competition_alt == 'None') or (competition == 'Super League 1' OR competition_alt == 'Super League Greece')) and season == 2017/2018
#
# Problem :
# UEFA | Poland | Ekstraklasa - None | 2018/2019
# In Fixture :
# confederation == 'UEFA' and region == 'Poland' and ((competition == 'Ekstraklasa' OR competition_alt == 'None') or (competition == 'Super League 1' OR competition_alt == 'Super League Greece')) and season == 2018/2019
#
# Problem :
# UEFA | Poland | Ekstraklasa - None | 2019/2020
# In Fixture :
# confederation == 'UEFA' and region == 'Poland' and ((competition == 'Ekstraklasa' OR competition_alt == 'None') or (competition == 'Super League 1' OR competition_alt == 'Super League Greece')) and season == 2019/2020
#
# Problem :
# UEFA | Poland | Ekstraklasa - None | 2020/2021
# In Fixture :
# confederation == 'UEFA' and region == 'Poland' and ((competition == 'Ekstraklasa' OR competition_alt == 'None') or (competition == 'Super League 1' OR competition_alt == 'Super League Greece')) and season == 2020/2021
#
# Problem :
# UEFA | Poland | Ekstraklasa - None | 2021/2022
# In Fixture :
# confederation == 'UEFA' and region == 'Poland' and ((competition == 'Ekstraklasa' OR competition_alt == 'None') or (competition == 'Super League 1' OR competition_alt == 'Super League Greece')) and season == 2021/2022
#
# Problem :
# UEFA | Poland | Ekstraklasa - None | 2022/2023
# In Fixture :
# confederation == 'UEFA' and region == 'Poland' and ((competition == 'Ekstraklasa' OR competition_alt == 'None') or (competition == 'Super League 1' OR competition_alt == 'Super League Greece')) and season == 2022/2023
#
# Problem :
# UEFA | Poland | Ekstraklasa - None | 2023/2024
# In Fixture :
# confederation == 'UEFA' and region == 'Poland' and ((competition == 'Ekstraklasa' OR competition_alt == 'None') or (competition == 'Super League 1' OR competition_alt == 'Super League Greece')) and season == 2023/2024
#
# Problem :
# UEFA | Republic of Ireland | Premier Division - None | 2018
# In Fixture :
# confederation == 'UEFA' and region == 'Republic of Ireland' and ((competition == 'Premier Division' OR competition_alt == 'None') or (competition == 'Super League 1' OR competition_alt == 'Super League Greece')) and season == 2018
#
# Problem :
# UEFA | Republic of Ireland | Premier Division - None | 2019
# In Fixture :
# confederation == 'UEFA' and region == 'Republic of Ireland' and ((competition == 'Premier Division' OR competition_alt == 'None') or (competition == 'Super League 1' OR competition_alt == 'Super League Greece')) and season == 2019
#
# Problem :
# UEFA | Republic of Ireland | Premier Division - None | 2020
# In Fixture :
# confederation == 'UEFA' and region == 'Republic of Ireland' and ((competition == 'Premier Division' OR competition_alt == 'None') or (competition == 'Super League 1' OR competition_alt == 'Super League Greece')) and season == 2020
#
# Problem :
# UEFA | Republic of Ireland | Premier Division - None | 2021
# In Fixture :
# confederation == 'UEFA' and region == 'Republic of Ireland' and ((competition == 'Premier Division' OR competition_alt == 'None') or (competition == 'Super League 1' OR competition_alt == 'Super League Greece')) and season == 2021
#
# Problem :
# UEFA | Republic of Ireland | Premier Division - None | 2022
# In Fixture :
# confederation == 'UEFA' and region == 'Republic of Ireland' and ((competition == 'Premier Division' OR competition_alt == 'None') or (competition == 'Super League 1' OR competition_alt == 'Super League Greece')) and season == 2022
#
# Problem :
# UEFA | Republic of Ireland | Premier Division - None | 2023
# In Fixture :
# confederation == 'UEFA' and region == 'Republic of Ireland' and ((competition == 'Premier Division' OR competition_alt == 'None') or (competition == 'Super League 1' OR competition_alt == 'Super League Greece')) and season == 2023
#
# Problem :
# UEFA | Republic of Ireland | Premier Division - None | 2024
# In Fixture :
# confederation == 'UEFA' and region == 'Republic of Ireland' and ((competition == 'Premier Division' OR competition_alt == 'None') or (competition == 'Super League 1' OR competition_alt == 'Super League Greece')) and season == 2024
#
# Problem :
# UEFA | Scotland | Premiership - Premiership | 2017/2018
# In Fixture :
# confederation == 'UEFA' and region == 'Scotland' and ((competition == 'Premiership' OR competition_alt == 'Premiership') or (competition == 'Super League 1' OR competition_alt == 'Super League Greece')) and season == 2017/2018
#
# Problem :
# UEFA | Scotland | Premiership - Premiership | 2018/2019
# In Fixture :
# confederation == 'UEFA' and region == 'Scotland' and ((competition == 'Premiership' OR competition_alt == 'Premiership') or (competition == 'Super League 1' OR competition_alt == 'Super League Greece')) and season == 2018/2019
#
# Problem :
# UEFA | Scotland | Premiership - Premiership | 2019/2020
# In Fixture :
# confederation == 'UEFA' and region == 'Scotland' and ((competition == 'Premiership' OR competition_alt == 'Premiership') or (competition == 'Super League 1' OR competition_alt == 'Super League Greece')) and season == 2019/2020
#
# Problem :
# UEFA | Scotland | Premiership - Premiership | 2020/2021
# In Fixture :
# confederation == 'UEFA' and region == 'Scotland' and ((competition == 'Premiership' OR competition_alt == 'Premiership') or (competition == 'Super League 1' OR competition_alt == 'Super League Greece')) and season == 2020/2021
#
# Problem :
# UEFA | Scotland | Premiership - Premiership | 2021/2022
# In Fixture :
# confederation == 'UEFA' and region == 'Scotland' and ((competition == 'Premiership' OR competition_alt == 'Premiership') or (competition == 'Super League 1' OR competition_alt == 'Super League Greece')) and season == 2021/2022
#
# Problem :
# UEFA | Slovakia | 1 liga - None | 2020/2021
# In Fixture :
# confederation == 'UEFA' and region == 'Slovakia' and ((competition == '1 liga' OR competition_alt == 'None') or (competition == '1. liga' OR competition_alt == 'None')) and season == 2020/2021
#
# Problem :
# UEFA | Slovakia | 1 liga - None | 2021/2022
# In Fixture :
# confederation == 'UEFA' and region == 'Slovakia' and ((competition == '1 liga' OR competition_alt == 'None') or (competition == '1. liga' OR competition_alt == 'None')) and season == 2021/2022
#
# Problem :
# UEFA | Slovakia | 1 liga - None | 2022/2023
# In Fixture :
# confederation == 'UEFA' and region == 'Slovakia' and ((competition == '1 liga' OR competition_alt == 'None') or (competition == '1. liga' OR competition_alt == 'None')) and season == 2022/2023
#
# Problem :
# UEFA | Slovakia | 1 liga - None | 2023/2024
# In Fixture :
# confederation == 'UEFA' and region == 'Slovakia' and ((competition == '1 liga' OR competition_alt == 'None') or (competition == '1. liga' OR competition_alt == 'None')) and season == 2023/2024
#
# Problem :
# UEFA | Spain | Segunda División - Segunda Division | 2018/2019
# In Fixture :
# confederation == 'UEFA' and region == 'Spain' and ((competition == 'Segunda División' OR competition_alt == 'Segunda Division') or (competition == '1. SNL' OR competition_alt == 'None')) and season == 2018/2019
#
# Problem :
# UEFA | Spain | Segunda División - Segunda Division | 2019/2020
# In Fixture :
# confederation == 'UEFA' and region == 'Spain' and ((competition == 'Segunda División' OR competition_alt == 'Segunda Division') or (competition == '1. SNL' OR competition_alt == 'None')) and season == 2019/2020
#
# Problem :
# UEFA | Spain | Segunda División - Segunda Division | 2020/2021
# In Fixture :
# confederation == 'UEFA' and region == 'Spain' and ((competition == 'Segunda División' OR competition_alt == 'Segunda Division') or (competition == '1. SNL' OR competition_alt == 'None')) and season == 2020/2021
#
# Problem :
# UEFA | Spain | Segunda División - Segunda Division | 2021/2022
# In Fixture :
# confederation == 'UEFA' and region == 'Spain' and ((competition == 'Segunda División' OR competition_alt == 'Segunda Division') or (competition == '1. SNL' OR competition_alt == 'None')) and season == 2021/2022
#
# Problem :
# UEFA | Spain | Segunda División - Segunda Division | 2022/2023
# In Fixture :
# confederation == 'UEFA' and region == 'Spain' and ((competition == 'Segunda División' OR competition_alt == 'Segunda Division') or (competition == '1. SNL' OR competition_alt == 'None')) and season == 2022/2023
#
# Problem :
# UEFA | Spain | Segunda División - Segunda Division | 2023/2024
# In Fixture :
# confederation == 'UEFA' and region == 'Spain' and ((competition == 'Segunda División' OR competition_alt == 'Segunda Division') or (competition == '1. SNL' OR competition_alt == 'None')) and season == 2023/2024

# %%
results_df = pd.DataFrame()
issues = []
for i, row in fixture_df.iterrows():
    confed = row.get('confederation')
    reg = row.get('region')
    comp = row.get('competition')
    comp_alt = row.get('competition_alt')
    seas = row.get('season')
    fx = row.get('fixture_count')
    
    # # Build the query safely using @
    # query_string = "confederation == @confed and region == @reg and (competition == @comp or competition == @comp_alt) and season == @seas"
    
    # --- 2. Clean the parameters (lower case, remove '.') ---
    #    Handles cases where the values might be None or not strings
    comp_clean = str(comp).lower().replace('.', '') if comp else ''
    comp_alt_clean = str(comp_alt).lower().replace('.', '') if comp_alt else ''


    # --- 3. Build the boolean conditions ---
    #    .str.lower() makes the comparison case-insensitive
    #    .str.replace('.', '') removes periods before comparing
    condition = (
        (misc_df['confederation'].str.lower() == confed.lower()) &
        (misc_df['region'].str.lower() == reg.lower()) &
        (misc_df['season'].str.lower() == seas.lower()) &
        (
            (misc_df['competition'].str.lower().str.replace('.', '', regex=False) == comp_clean) |
            (misc_df['competition'].str.lower().str.replace('.', '', regex=False) == comp_alt_clean)
        )
    )

    # --- 4. Apply the filter and append the results ---
    df = misc_df[condition]
    # df = misc_df.query(query_string)
    if df.shape[0] > 0 :
        first_row =  df.head(1)
        first_row['Total_Fixtures'] = fx
        results_df = pd.concat([results_df, first_row], ignore_index=True)
    else:
        print("Problem : ")
        print(f"{confed} | {reg} | {comp} | {seas}")
        print("In Fixture : \n"
        f"confederation == '{confed}' and "
        f"region == '{reg}' and "
        f"(competition == '{comp}' or "
        f"competition_alt == '{comp}') and "
        f"season == '{seas}'"
        )
        issues.append(f"{reg} | {comp}")
        print()
results_df.head()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# Problem :
# CONMEBOL | Colombia | Primera A | 2025
# In Fixture :
# confederation == 'CONMEBOL' and region == 'Colombia' and (competition == 'Primera A' or competition_alt == 'Primera A') and season == '2025'
#
# Problem :
# CONMEBOL | Peru | Liga 1 | 2025
# In Fixture :
# confederation == 'CONMEBOL' and region == 'Peru' and (competition == 'Liga 1' or competition_alt == 'Liga 1') and season == '2025'
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# ...
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
# C:\Users\Hp\AppData\Local\Temp\ipykernel_8068\1789666973.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_row['Total_Fixtures'] = fx
#   batch confederation     region   competition     season    type  matches  \
# 0    B6           AFC  Australia  A-League Men  2017/2018  events      140
# 1    B6           AFC  Australia  A-League Men  2018/2019  events      129
# 2    B6           AFC  Australia  A-League Men  2019/2020  events      148
# 3    B6           AFC  Australia  A-League Men  2020/2021  events      161
# 4    B6           AFC  Australia  A-League Men  2021/2022  events      163
#
#    team_counts  total_fixtures  Total_Fixtures
# 0           10           140.0           140.0
# 1           10           140.0           140.0
# 2           11           148.0           148.0
# 3           12           161.0           161.0
# 4           12           163.0           163.0

# %% [markdown]
# ### Check Here for the merged df

# %%
all_df = pd.read_excel("COMPARE_CLEANED_DATA.xlsx")
all_df.head(7)
# Out:
#   batch_x confederation region                 competition     season    type  \
# 0      B6           AFC    AFC  AFC Champions League Elite       2018  events
# 1      B6           AFC    AFC  AFC Champions League Elite       2019  events
# 2      B6           AFC    AFC  AFC Champions League Elite       2020  events
# 3      B6           AFC    AFC  AFC Champions League Elite       2021  events
# 4      B6           AFC    AFC  AFC Champions League Elite       2022  events
# 5      B6           AFC    AFC  AFC Champions League Elite  2023/2024  events
# 6      B6           AFC    AFC  AFC Champions League Elite  2024/2025  events
#
#    matches  team_counts batch_y  fixture_count       competition_alt
# 0      140           46      B1          140.0  AFC Champions League
# 1      145           51      B1          145.0  AFC Champions League
# 2      113           49      B1          113.0  AFC Champions League
# 3      140           45      B1          140.0  AFC Champions League
# 4      127           46      B1          137.0  AFC Champions League
# 5      163           53      B1          163.0  AFC Champions League
# 6      114           27      B1          114.0  AFC Champions League

# %%
Competition.objects.all()[0].__dict__
# Out:
# {'_state': <django.db.models.base.ModelState at 0x15b8c2e2350>,
#  'id': 1,
#  'confederation': 'AFC',
#  'country': 'AFC',
#  'competition_name': 'AFC Champions League',
#  'name_scoresaway': 'AFC Champions League Elite',
#  'name_fotmob': 'AFC Champions League Elite',
#  'competition_format': 'H',
#  'competition_type': 'I',
#  'season_start': 7,
#  'season_end': 6,
#  'event_data_available': True,
#  'event_data_url': 'https://www.scoresway.com/en_GB/soccer/afc-champions-league-elite-2024-2025/6ae0gn489uln4bm2q7ir6ruok/fixtures',
#  'shot_data_available': False,
#  'shot_data_url': ''}

# %%
for _, row in all_df.iterrows():
    q |= Q(confederation=row["confederation"],
           country=row["region"],
           competition_name=row["competition"],
           
          )

# %%
all_df[(all_df['fixture_count'].isna()) | (all_df['diff'] > 0)].to_excel("Retry_Items.xlsx",index=False)

# %%
comp_to_alt_map = {}
for i,row in all_df[['competition','competition_alt']].iterrows():
    comp = row.get("competition")
    comp_alt = row.get("competition_alt")
    if comp in comp_to_alt_map :
        # print("- ",comp)
        if len(comp_to_alt_map[comp]) != 0 or len(comp_to_alt_map[comp]) != 'nan'  :
            continue
    # if len(comp_to_alt_map[comp]) != 0 :
    #     continue
    comp_to_alt_map[comp] = str(comp_alt)
    if "1" in comp or "2" in comp :
        print(f"comp_to_alt['{comp}'] = {comp_alt}")
print(",".join(sorted([f"'{k}'" for k,v in comp_to_alt_map.items() if 'nan' in v.lower()])))
# Out:
# comp_to_alt['J1 League'] = J1 League
# comp_to_alt['Thai League 1'] = Thai League 1
# comp_to_alt['Liga 1'] = Liga 1
# comp_to_alt['1 Division'] = nan
# comp_to_alt['Ligue 1'] = nan
# comp_to_alt['Ligue 2'] = Ligue 2
# comp_to_alt['2 Bundesliga'] = nan
# comp_to_alt['Super League 1'] = Super League Greece
# comp_to_alt['1 liga'] = nan
# comp_to_alt['1 SNL'] = nan
# comp_to_alt['1 Lig'] = nan
# '1 Division','1 Lig','1 SNL','1 liga','2 Bundesliga','Ekstraklasa','Eliteserien','League Two','Ligue 1','Premier Division','Premiership','Virsliga'

# %%
from base_app.helpers import get_name_mappings

# %%
get_name_mappings(source='sa',target="n",source_as_file_name=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 get_name_mappings(source='sa',target="n",source_as_file_name=True)
#
# TypeError: get_name_mappings() got an unexpected keyword argument 'source_as_file_name'

# %% [markdown]
# Here I've somehow figured out which ones needs to be done again. Now onto the shot details

# %% [markdown]
# ## Fetch Shot Data retries

# %%
def get_all_shot_files(directory_path="D:\All Season Data\Files"):
    files_data = []
    fl = False
    for lvl_1,lvl_2,file_list in os.walk(directory_path,):
        if file_list == []:
            continue
        batch_no = next((x.split("_")[0].capitalize() for x in lvl_1.split("\\") if "_MetaData" in x),"B6")
        confederation,region = [x.strip(" ") for x in lvl_1.split("\\") ][-2:]
        for file_name in file_list :
            if 'shots.xlsx' not in file_name :
                continue
            df = None
            temp = {}
            temp['batch'] = batch_no
            temp['confederation'] = confederation
            temp['region'] = region
            temp = {**temp,**filter_file_details(file_name)}
            try :
                df = pd.read_excel(f"{lvl_1}/{file_name}")
                temp['matches'] = df.shape[0]
                temp['team_counts'] = len(set(list(set(df['home_team']))+list(set(df['away_team'])))) 
                del df
            except :
                temp['team_counts'] = 0 
                temp['matches'] = 0
                if dl:
                    del df
            files_data.append(temp)
        
    return pd.DataFrame(files_data)
shots_df = get_all_shot_files()

# %%
shots_df.head()
# Out:
#   batch confederation     region competition     season   type  matches  \
# 0    B1           AFC  Australia    A-League  2017/2018  shots      140
# 1    B1           AFC  Australia    A-League  2018/2019  shots      140
# 2    B1           AFC  Australia    A-League  2019/2020  shots      148
# 3    B1           AFC  Australia    A-League  2020/2021  shots      161
# 4    B1           AFC  Australia    A-League  2021/2022  shots      163
#
#    team_counts
# 0           10
# 1           10
# 2           11
# 3           12
# 4           12

# %%
shots = shots_df.drop(['batch'],axis=1).drop_duplicates()

# %%
all_seasons = Season.objects.all().exclude(season_shot_url='')

# %%
results_shots = pd.DataFrame()
missing = []
for shot_ssn in all_seasons :
    s_name = shot_ssn.name
    c_name = shot_ssn.competition.competition_name
    conf = shot_ssn.competition.confederation
    region = shot_ssn.competition.country

    comp_clean = str(c_name).lower().replace('.', '') if c_name else ''


    # --- 3. Build the boolean conditions ---
    #    .str.lower() makes the comparison case-insensitive
    #    .str.replace('.', '') removes periods before comparing
    condition = (
        (shots['confederation'].str.lower() == conf.lower()) &
        (shots['region'].str.lower() == region.lower()) &
        (shots['season'].str.lower() == s_name.lower())# &
        # (shots['competition'].str.lower().str.replace('.', '', regex=False) == comp_clean)
    )
# --- 4. Apply the filter and append the results ---
    df = shots[condition]
    # df = misc_df.query(query_string)
    if df.shape[0] > 0 :
        # first_row =  )
        # loc[0, 'Total_Fixtures'] = 
        results_shots = pd.concat([results_shots, df.head(1)], ignore_index=True)
    else:
        temp = {}
        temp['Confederation'] = conf
        temp['Region'] = region
        temp['Competition'] = c_name
        temp['Season'] = s_name
        missing.append(temp)

# %%
results_shots.shape, len(missing)
# Out:
# ((135, 7), 59)

# %%
print(f"Total : {len(all_seasons)} | Found : {shots.shape[0]} | Left : {len(all_seasons) - shots.shape[0] }")
# Out:
# Total : 194 | Found : 127 | Left : 67

# %%
results_df
# Out:
#     batch confederation       region       competition     season    type  \
# 0      B6           AFC    Australia      A-League Men  2017/2018  events
# 1      B6           AFC    Australia      A-League Men  2018/2019  events
# 2      B6           AFC    Australia      A-League Men  2019/2020  events
# 3      B6           AFC    Australia      A-League Men  2020/2021  events
# 4      B6           AFC    Australia      A-League Men  2021/2022  events
# ..    ...           ...          ...               ...        ...     ...
# 446    B6          UEFA  Switzerland  Challenge League  2024/2025  events
# 447    B6          UEFA  Switzerland      Super League  2017/2018  events
# 448    B6          UEFA  Switzerland      Super League  2018/2019  events
# 449    B6          UEFA  Switzerland      Super League  2019/2020  events
# 450    B6          UEFA      Türkiye             1 Lig  2020/2021  events
#
#      matches  team_counts  total_fixtures  Total_Fixtures
# 0        140           10           140.0           140.0
# 1        129           10           140.0           140.0
# 2        148           11           148.0           148.0
# 3        161           12           161.0           161.0
# 4        163           12           163.0           163.0
# ..       ...          ...             ...             ...
# 446      180           10           180.0           180.0
# 447      179           10           180.0           180.0
# 448       59           10           180.0           180.0
# 449      180           10           180.0           180.0
# 450      311           18             NaN           311.0
#
# [451 rows x 10 columns]
