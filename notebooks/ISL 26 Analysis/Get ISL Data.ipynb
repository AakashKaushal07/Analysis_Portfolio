# %%
from leagues.models import Competition,Season
from base_app.helpers import best_fuzzy_match
from games.models import Game
from datetime import datetime
import pandas as pd
import numpy as np
import os
from base_app.models import OptaEvents,OptaQualifier

# %%
isl_seasons = Season.objects.filter(competition__id=5).order_by('-name')

# %%
recent_seasons = isl_seasons[:2]

# %%
q_df = pd.read_csv(r"D:\Analysis_Portfolio\notebooks\ISL 26 Analysis\Sources\New folder\opta-qualifiers.csv")
e_df = pd.read_csv(r"D:\Analysis_Portfolio\notebooks\ISL 26 Analysis\Sources\OptaEvents.csv")

# %%
# for i, row in q_df.iterrows():
#     OptaQualifier.objects.get_or_create(
#         opta_id = row['ID'],
#         qualifier_name = row['name'],
#         description = row['description']
#     )

for i, row in e_df.iterrows():
    OptaEvents.objects.get_or_create(
        opta_id = row['ID'],
        event_name = row['Type'],
        description = row['Description']
    )
# Out:
# ---------------------------------------------------------------------------
# DoesNotExist                              Traceback (most recent call last)
# File D:\Analysis_Portfolio\my-venv\Lib\site-packages\django\db\models\query.py:946, in QuerySet.get_or_create(self, defaults, **kwargs)
#     945 try:
# --> 946     return self.get(**kwargs), False
#     947 except self.model.DoesNotExist:
#
# File D:\Analysis_Portfolio\my-venv\Lib\site-packages\django\db\models\query.py:633, in QuerySet.get(self, *args, **kwargs)
#     632 if not num:
# --> 633     raise self.model.DoesNotExist(
#     634         "%s matching query does not exist." % self.model._meta.object_name
#     635     )
#     636 raise self.model.MultipleObjectsReturned(
#     637     "get() returned more than one %s -- it returned %s!"
#     638     % (
#    (...)    641     )
#     642 )
#
# DoesNotExist: OptaEvents matching query does not exist.
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
sorted([k for k,v in q_df.value_counts('ID').to_dict().items() if v >1])
# Out:
# [228, 235, 236, 238, 241, 266]

# %%
row
# Out:
# Unnamed: 0                             17
# ID                                     18
# Type                           Player off
# Description    Player is substituted off
# Name: 68, dtype: object
