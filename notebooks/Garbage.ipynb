# %%
cols = """2017/2018
2017/2018
2017/2018
2017/2018
2017/2018
2017/2018
2017/2018
2017/2018
2017/2018
2017/2018
2017/2018
2017/2018
2017/2018
2017/2018
2017/2018
2017/2018
2017/2018
2017/2018
2017/2018
2017/2018
2017/2018
2017/2018
2017/2018
2017/2018
2017/2018
2017/2018
2017/2018
2017/2018
2017/2018
2017/2018
2017/2018
2017/2018
2017/2018
2017/2018
2017/2018
2017/2018
2017/2018
2017/2018
2017/2018
2017/2018
2017/2018
2017/2018
2017/2018
2017/2018
2017/2018 - Apertura
2018
2018
2018
2018
2018
2018
2018
2018
2018
2018
2018
2018
2018
2018
2018
2018
2018
2018
2018
2018
2018
2018
2018
2018
2018/2019
2018/2019
2018/2019
2018/2019
2018/2019
2018/2019
2018/2019
2018/2019
2018/2019
2018/2019
2018/2019
2018/2019
2018/2019
2018/2019
2018/2019
2018/2019
2018/2019
2018/2019
2018/2019
2018/2019
2018/2019
2018/2019
2018/2019
2018/2019
2018/2019
2018/2019
2018/2019
2018/2019
2018/2019
2018/2019
2018/2019
2018/2019
2018/2019
2018/2019
2018/2019
2018/2019
2018/2019
2018/2019
2018/2019
2018/2019
2018/2019
2018/2019
2018/2019
2018/2019
2018/2019
2018/2019
2018/2019 - Apertura
2018/2019 - Clausura
2019
2019
2019
2019
2019
2019
2019
2019
2019
2019
2019
2019
2019
2019
2019
2019
2019
2019
2019
2019
2019
2019
2019
2019/2020
2019/2020
2019/2020
2019/2020
2019/2020
2019/2020
2019/2020
2019/2020
2019/2020
2019/2020
2019/2020
2019/2020
2019/2020
2019/2020
2019/2020
2019/2020
2019/2020
2019/2020
2019/2020
2019/2020
2019/2020
2019/2020
2019/2020
2019/2020
2019/2020
2019/2020
2019/2020
2019/2020
2019/2020
2019/2020
2019/2020
2019/2020
2019/2020
2019/2020
2019/2020
2019/2020
2019/2020
2019/2020
2019/2020
2019/2020
2019/2020
2019/2020
2019/2020
2019/2020
2019/2020
2019/2020
2019/2020 - Apertura
2019/2020 - Clausura
2020
2020
2020
2020
2020
2020
2020
2020
2020
2020
2020
2020
2020
2020
2020
2020
2020
2020
2020
2020
2020
2020
2020
2020/2021
2020/2021
2020/2021
2020/2021
2020/2021
2020/2021
2020/2021
2020/2021
2020/2021
2020/2021
2020/2021
2020/2021
2020/2021
2020/2021
2020/2021
2020/2021
2020/2021
2020/2021
2020/2021
2020/2021
2020/2021
2020/2021
2020/2021
2020/2021
2020/2021
2020/2021
2020/2021
2020/2021
2020/2021
2020/2021
2020/2021
2020/2021
2020/2021
2020/2021
2020/2021
2020/2021
2020/2021
2020/2021
2020/2021
2020/2021
2020/2021
2020/2021
2020/2021
2020/2021
2020/2021
2020/2021
2020/2021 - Apertura
2020/2021 - Clausura
2021
2021
2021
2021
2021
2021
2021
2021
2021
2021
2021
2021
2021
2021
2021
2021
2021
2021
2021
2021
2021
2021
2021
2021/2022
2021/2022
2021/2022
2021/2022
2021/2022
2021/2022
2021/2022
2021/2022
2021/2022
2021/2022
2021/2022
2021/2022
2021/2022
2021/2022
2021/2022
2021/2022
2021/2022
2021/2022
2021/2022
2021/2022
2021/2022
2021/2022
2021/2022
2021/2022
2021/2022
2021/2022
2021/2022
2021/2022
2021/2022
2021/2022
2021/2022
2021/2022
2021/2022
2021/2022
2021/2022
2021/2022
2021/2022
2021/2022
2021/2022
2021/2022
2021/2022
2021/2022
2021/2022
2021/2022
2021/2022
2021/2022
2021/2022
2021/2022 - Apertura
2021/2022 - Clausura
2022
2022
2022
2022
2022
2022
2022
2022
2022
2022
2022
2022
2022
2022
2022
2022
2022
2022
2022
2022
2022
2022
2022
2022/2023
2022/2023
2022/2023
2022/2023
2022/2023
2022/2023
2022/2023
2022/2023
2022/2023
2022/2023
2022/2023
2022/2023
2022/2023
2022/2023
2022/2023
2022/2023
2022/2023
2022/2023
2022/2023
2022/2023
2022/2023
2022/2023
2022/2023
2022/2023
2022/2023
2022/2023
2022/2023
2022/2023
2022/2023
2022/2023
2022/2023
2022/2023
2022/2023
2022/2023
2022/2023
2022/2023
2022/2023
2022/2023
2022/2023
2022/2023
2022/2023
2022/2023
2022/2023
2022/2023
2022/2023
2022/2023
2022/2023
2022/2023 - Apertura
2022/2023 - Clausura
2023
2023
2023
2023
2023
2023
2023
2023
2023
2023
2023
2023
2023
2023
2023
2023
2023
2023
2023
2023
2023
2023/2024
2023/2024
2023/2024
2023/2024
2023/2024
2023/2024
2023/2024
2023/2024
2023/2024
2023/2024
2023/2024
2023/2024
2023/2024
2023/2024
2023/2024
2023/2024
2023/2024
2023/2024
2023/2024
2023/2024
2023/2024
2023/2024
2023/2024
2023/2024
2023/2024
2023/2024
2023/2024
2023/2024
2023/2024
2023/2024
2023/2024
2023/2024
2023/2024
2023/2024
2023/2024
2023/2024
2023/2024
2023/2024
2023/2024
2023/2024
2023/2024
2023/2024
2023/2024
2023/2024
2023/2024
2023/2024
2023/2024
2023/2024
2023/2024
2023/2024 - Apertura
2023/2024 - Clausura
2024
2024
2024
2024
2024
2024
2024
2024
2024
2024
2024
2024
2024
2024
2024
2024
2024
2024
2024
2024
2024
2024/2025
2024/2025
2024/2025
2024/2025
2024/2025
2024/2025
2024/2025
2024/2025
2024/2025
2024/2025
2024/2025
2024/2025
2024/2025
2024/2025
2024/2025
2024/2025
2024/2025
2024/2025
2024/2025
2024/2025
2024/2025
2024/2025
2024/2025
2024/2025
2024/2025
2024/2025
2024/2025
2024/2025
2024/2025
2024/2025
2024/2025
2024/2025
2024/2025
2024/2025
2024/2025
2024/2025
2024/2025
2024/2025
2024/2025
2024/2025
2024/2025
2024/2025
2024/2025
2024/2025
2024/2025
2024/2025
2024/2025
2024/2025
2024/2025
2024/2025 - Apertura
2024/2025 - Clausura
2025
2025
2025
2025
2025
2025
2025
2025
2025
2025
2025
2025
2025
2025
2025
2025
2025
2025
2025
2025
2025
2025/2026
2025/2026
""".split("\n")

# %%
cols = list(set(cols))

# %%
from pprint import pprint

# %%
pprint({x:x.count("20") for x in cols})
# Out:
# {'': 0,
#  '2017/2018': 2,
#  '2017/2018 - Apertura': 2,
#  '2018': 1,
#  '2018/2019': 2,
#  '2018/2019 - Apertura': 2,
#  '2018/2019 - Clausura': 2,
#  '2019': 1,
#  '2019/2020': 3,
#  '2019/2020 - Apertura': 3,
#  '2019/2020 - Clausura': 3,
#  '2020': 2,
#  '2020/2021': 3,
#  '2020/2021 - Apertura': 3,
#  '2020/2021 - Clausura': 3,
#  '2021': 1,
#  '2021/2022': 2,
#  '2021/2022 - Apertura': 2,
#  '2021/2022 - Clausura': 2,
#  '2022': 1,
#  '2022/2023': 2,
#  '2022/2023 - Apertura': 2,
#  '2022/2023 - Clausura': 2,
#  '2023': 1,
#  '2023/2024': 2,
#  '2023/2024 - Apertura': 2,
#  '2023/2024 - Clausura': 2,
#  '2024': 1,
#  '2024/2025': 2,
#  '2024/2025 - Apertura': 2,
#  '2024/2025 - Clausura': 2,
#  '2025': 1,
#  '2025/2026': 2}

# %%
examples = [
    "2020/2021 - Apertura",
    "2019 - Clausura",
    "2018/2019 - La Liga - Final",
    "2022/2023",
    "2020/2021 – Final Round",
    "2021 – Group Stage",
    "2024"
]

for s in examples:
    match = re.match(r"^(?P<year>\d{4}(?:/\d{4})?)\s*[-–]?\s*(?P<stage>.*)?$", s)
    if match:
        year = match.group("year")
        stage = match.group("stage").strip() if match.group("stage") else None
        print(f"{s} → year: {year}, stage/league: {stage}")
# Out:
# 2020/2021 - Apertura → year: 2020/2021, stage/league: Apertura
# 2019 - Clausura → year: 2019, stage/league: Clausura
# 2018/2019 - La Liga - Final → year: 2018/2019, stage/league: La Liga - Final
# 2022/2023 → year: 2022/2023, stage/league: None
# 2020/2021 – Final Round → year: 2020/2021, stage/league: Final Round
# 2021 – Group Stage → year: 2021, stage/league: Group Stage
# 2024 → year: 2024, stage/league: None
